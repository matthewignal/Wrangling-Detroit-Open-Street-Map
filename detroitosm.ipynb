# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET

# File can be found courtesy of MapZen
# https://mapzen.com/data/metro-extracts/
OSM_FILE = "detroit_michigan.osm"
filename = OSM_FILE

# %%
import pprint
import re
def count_tags(filename):
    tags={}
    for event, elem in ET.iterparse(filename):
        if type(elem.tag)=='None':
            pass
        if elem.tag not in tags.keys():
            tags[elem.tag] = 1
        else:
            tags[elem.tag] += 1
    return tags
   
tags = count_tags(filename)
pprint.pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 45327,
#  'nd': 4229236,
#  'node': 3699172,
#  'osm': 1,
#  'relation': 5682,
#  'tag': 2006880,
#  'way': 363821}

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        key = element.get('k')
        if re.search(lower, key):
            keys['lower'] += 1
        elif re.search(lower_colon, key):
            keys['lower_colon'] += 1
        elif re.search(problemchars, key):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

def test():
    keys = process_map(filename)
    pprint.pprint(keys)
test()
# Out:
# {'lower': 909638, 'lower_colon': 967712, 'other': 129527, 'problemchars': 3}

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Circle", "Crescent", "Bluff", "North", "South", "East", "West",
           "Grove", "Highway", "Line", "Mall", "Park", "Sideroad", "Triangle", "Way"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(filename):
    osm_file = open(filename, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(filename, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types
audit(filename)
# Out:
# defaultdict(set,
#             {'1': {'Concession Road 1', 'Kent Road 1'},
#              '10': {'Concession Road 10', 'Sideroad 9 & 10'},
#              '100': {'Orchard Hill Place, Suite 100'},
#              '11': {'Concession Road 11', 'County Road 11'},
#              '12': {'Concession Road 12',
#               'County Road 12',
#               'East Old US 12',
#               'East Old US Hwy 12',
#               'US 12'},
#              '13': {'Concession Road 13', 'Sideroad 12 & 13'},
#              '14': {'Concession Road 14',
#               'County Road 14',
#               'Sideroad 13 & 14'},
#              '15': {'County Road 15'},
#              '17': {'Sideroad 16 & 17'},
#              '18': {'County Road 11 & 18', 'County Road 18'},
#              '19': {'Sideroad 18 & 19'},
#              '1a': {'Concession Road 1a'},
#              '2': {'Concession Road 2', 'County Road 2'},
#              '20': {'County Road 20'},
#              '202': {'Wilshire Drive, Suite 202'},
#              '203': {'North Center Street, Suite 203'},
#              '22': {'County Road 22'},
#              '223': {'New US 223'},
#              '23': {'County Road 23', 'Old US Highway 23'},
#              '3': {'8th Concession Road, R.R. #3',
#               'Concession Road 3',
#               'Kings Highway 3'},
#              '300': {'Grand River Ave #300'},
#              '31': {'County Road  31', 'County Road 31'},
#              '34': {'County Road 34'},
#              '36': {'East M 36'},
#              '37': {'County Road 37'},
#              '4': {'Concession Road 4'},
#              '40': {'Green Hill Road Apt 40', 'Highway 40'},
#              '41': {'County Road 41'},
#              '42': {'County Road 42'},
#              '46': {'County Road 46'},
#              '46596': {'46596'},
#              '5': {'Concession Road 5'},
#              '50': {'County Road 50'},
#              '6': {'Concession Road 6'},
#              '6a': {'Concession Road 6a'},
#              '7': {'Concession Road 7', 'Sideroad 6 & 7'},
#              '77': {'Highway 77'},
#              '8': {'Concession Road 8', 'County Road 8'},
#              '9': {'Concession Road 9', 'County Road 9'},
#              'Albuna': {'Townline  Albuna'},
#              'Alfred': {'Alfred'},
#              'Alley': {'Dix Alley'},
#              'Ave': {'Baldwin Ave',
#               'Dougall Ave',
#               'E. Jefferson Ave',
#               'Edison Ave',
#               'Grand River Ave',
#               'Jackson Ave',
#               'Lincoln Ave',
#               'Little Mack Ave',
#               'Mandalay Ave',
#               'Michigan Ave',
#               'Ouellette Ave',
#               'S Grand Ave',
#               'S Grand River Ave',
#               'Van Dyke Ave',
#               'W Warren Ave',
#               'West Michigan Ave',
#               'Woodward Ave'},
#              'Ave.': {'Grand River Ave.',
#               'Jefferson Ave.',
#               'North Gratiot Ave.',
#               'W Grand River Ave.'},
#              'B.': {'Pine Grove Ave, Suite B.'},
#              'Baseline': {'Baseline'},
#              'Beach': {'Marentette Beach'},
#              'Belmont': {'Belmont'},
#              'Bend': {'Creek Bend', 'Harvest Bend', 'Horseshoe Bend'},
#              'Biddle': {'Biddle'},
#              'Blvd': {'W Boston Blvd', 'W South Blvd'},
#              'Blvd.': {'Little River Blvd.',
#               'R Grand Blvd.',
#               'W. Grand Blvd.',
#               'Washington Blvd.'},
#              'Broadway': {'Broadway'},
#              'Canfield': {'W. Canfield'},
#              'Caroline': {'Caroline'},
#              'Cass': {'Cass'},
#              'Cedarview': {'Cedarview'},
#              'Center': {'Renaissance Center'},
#              'Central': {'Central'},
#              'Centre': {'Chrysler Centre'},
#              'Chase': {'Steeple Chase'},
#              'Coast': {'Gold Coast'},
#              'Coolidge': {'W. Coolidge'},
#              'Ct': {'Armstrong Ct',
#               'Marquette Ct',
#               'Stone Wood Ct',
#               'Victoria Ct'},
#              'Davison': {'Davison'},
#              'Degurse': {'Degurse'},
#              'Dequindre': {'Dequindre'},
#              'Detroit': {'Mt Elliott St, Detroit'},
#              'Dr': {'Corporate Dr',
#               'E. Fisher Service Dr',
#               'E. Huron River Dr',
#               'Essex Dr',
#               'Shoreline Dr',
#               'Sierra Dr',
#               'Tallman Dr',
#               'Town Center Dr'},
#              'Dr.': {'Old Milford Farms Dr.', 'Westchester Dr.'},
#              'Dyke': {'Van Dyke'},
#              'E': {'Tecumseh Rd E'},
#              'Eisenhower': {'West Eisenhower'},
#              'Equestrian': {'Equestrian'},
#              'Estates': {'Eastgate Estates'},
#              'Evaline': {'Evaline'},
#              'Expressway': {'Southfield Expressway'},
#              'Fair': {'West State Fair'},
#              'Fenton': {'Fenton'},
#              'Forest': {'South Forest'},
#              'Gardens': {'Lexham Gardens',
#               'Marvin Gardens',
#               'St Clair Gardens'},
#              'Garfield': {'Garfield'},
#              'Glengary': {'Glengary'},
#              'Gosfield': {'Townline East Gosfield', 'Townline West Gosfield'},
#              'Gratiot': {'Gratiot'},
#              'Greenfield': {'Greenfield'},
#              'Hamlin': {'E Hamlin'},
#              'Heights': {'Washington Heights'},
#              'Hill': {'Ferry Dock Hill'},
#              'Hwy': {'Coolidge Hwy', 'Stephenson Hwy'},
#              'Jefferson': {'East Jefferson'},
#              'Kinloch': {'Kinloch'},
#              'Labbe': {'Rue Labbe'},
#              'Lafayette': {'Avenue de Lafayette'},
#              'Lake': {'E Long Lake', 'East Square Lake'},
#              'Leathorne': {'Leathorne'},
#              'Lichfield': {'Lichfield'},
#              'Lincoln': {'West Lincoln'},
#              'Lothrop': {'Lothrop'},
#              'Malden': {'Townline Road Colchester South Malden'},
#              'Maple': {'35275 Silver Maple'},
#              'McNichols': {'West McNichols'},
#              'Middlebelt': {'Middlebelt'},
#              'Mile': {'6 Mile'},
#              'N': {'Interpark Dr N'},
#              'Olympia': {'Olympia'},
#              'Orland': {'Orland'},
#              'Orndorf': {'Charles H Orndorf'},
#              'Overland': {'Overland'},
#              'Pembroke': {'Pembroke'},
#              'Pkwy': {'Metropolitan Pkwy',
#               'Northfieild Pkwy',
#               'Northfield Pkwy'},
#              'Pl': {'Nicolet Pl', 'Orchard Hill Pl'},
#              'Pl.': {'Cottage Pl.', 'Edmund Pl.'},
#              'Plaza': {'Hurley Plaza', 'Jackson Plaza'},
#              'Point': {'Hingle Point'},
#              'Poplar': {'Poplar'},
#              'Quincy': {'Quincy'},
#              'Railway': {'Canada South Railway'},
#              'Rd': {'21 Mile Rd',
#               '32625 Industrial Rd',
#               '396 John R Rd',
#               '5 Mile Rd',
#               'Arsenal Rd',
#               'Auburn Rd',
#               'Belleville Rd',
#               'Bluebush Rd',
#               'Clark Rd',
#               'Coolidge Rd',
#               'Crooks Rd',
#               'Dequindre Rd',
#               'E 11 Mile Rd',
#               'E 15 Mile Rd',
#               'E 9 Mile Rd',
#               'E Big Beaver Rd',
#               'E Commerce Rd',
#               'E Long Lake Rd',
#               'E Maple Rd',
#               'East Dunbar Rd',
#               'Fisher Rd',
#               'Ford Rd',
#               'Haggerty Rd',
#               'Hall Rd',
#               'Hill Rd',
#               'Jackson Rd',
#               'John R Rd',
#               'Livernois Rd',
#               'Loop Rd',
#               'Mabley Hill Rd',
#               'N Ann Arbor Rd',
#               'N Maple Rd',
#               'N Squirrel Rd',
#               'Orchard Lake Rd',
#               'Rochester Rd',
#               'Ryan Rd',
#               'S Haggerty Rd',
#               'Sashabaw Rd',
#               'Shimmons Rd',
#               'Southfield Rd',
#               'Sterns Rd',
#               'Telegraph Rd',
#               'W 26 Mile Rd',
#               'W 7 Mile Rd',
#               'W Big Beaver Rd',
#               'W Long Lake Rd',
#               'W Maple Rd',
#               'W. Maple Rd',
#               'West Rd',
#               'Wixom Rd'},
#              'Rd.': {'Consear Rd.',
#               'E 12 Mile Rd.',
#               'E. Tienken Rd.',
#               'Lauzon Rd.',
#               'Sashabaw Rd.'},
#              'River': {'East Grand River',
#               'Grand River',
#               'W Grand River',
#               'W. Grand River'},
#              'Rochester': {'Townline Road Rochester'},
#              'Rose': {'St. Rose'},
#              'Row': {'Maple Row'},
#              'Run': {'Ruggles Run'},
#              'Saginaw': {'Saginaw'},
#              'Second': {'Second'},
#              'Service': {'Edsel Ford Fwy I- 94 Service'},
#              'Sheldon': {'Sheldon'},
#              'St': {'Alfred St',
#               'Barrington St',
#               'Broadway St',
#               'Burroughs St',
#               'Dennison St',
#               'E. Nevada St',
#               'Fort St',
#               'Lyndon St',
#               'Main St',
#               'S Main St',
#               'W Congress St',
#               'W Fort St'},
#              'St.': {'Alfred St.',
#               'Brush St.',
#               'Church St.',
#               'Griswold St.',
#               'Grove St.',
#               'Jerome St.',
#               'N. Main St.',
#               'Rockwood St.',
#               'Vinewood St.'},
#              'Starkweather': {'Starkweather'},
#              'Sugarbush': {'Sugarbush'},
#              'Sylvester': {'Sylvester'},
#              'Tecumseh': {'Tecumseh'},
#              'US-23': {'Old US-23'},
#              'Union': {'Main St Union'},
#              'Village': {'Country Village'},
#              'W': {'University Ave W'},
#              'W.': {'Pitt Street W.',
#               'Riverside Drive W.',
#               'Wyandotte St. W.'},
#              'Wagner': {'29217 Wagner'},
#              'Washington': {'Washington'},
#              'Woods': {'Carolina Woods'},
#              'Woodward': {'Woodward'},
#              'Wynd': {'Shorehaven Wynd'},
#              'Wyoming': {'Wyoming'},
#              'Yemans': {'Yemans'},
#              'ave': {'bordeaux ave'},
#              'il': {'E 14 st lockport il'},
#              'mile': {'6 mile'},
#              'road': {'Carpenter road', 'Packard road'},
#              'way': {'Lambeth way'}})

# %%
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Rd": "Road",
            "Rd.": "Road",
            "Ln.": "Lane",
            "Ln": "Lane",
            "N.": "North",
            "N" : "North",
            "S.": "South",
            "S": "South",
            "E.": "East",
            "E": "East",
            "W.": "West",
            "W": "West",
            "Pkwy": "Parkway",
            "Pkwy.": "Parkway",
            "Hwy": "Highway",
            "Hwy.": "Highway",
            "Blvd.": "Boulevard",
            "Blvd": "Boulevard",
            "Dr": "Drive",
            "Dr.": "Drive",
            "Pl" : "Place",
            "Pl." : "Place",
            "Cir" : "Circle",
            "Cir." : "Circle",
            "Ct." : "Court",
            "Ct" : "Court",
            }

def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping.keys():
            name = re.sub(m.group(), mapping[m.group()], name)
    return name
 

def test():
    st_types = audit(filename)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            
test()
# Out:
# {'1': set(['Concession Road 1', 'Kent Road 1']),
#  '10': set(['Concession Road 10', 'Sideroad 9 & 10']),
#  '100': set(['Orchard Hill Place, Suite 100']),
#  '11': set(['Concession Road 11', 'County Road 11']),
#  '12': set(['Concession Road 12',
#             'County Road 12',
#             'East Old US 12',
#             'East Old US Hwy 12',
#             'US 12']),
#  '13': set(['Concession Road 13', 'Sideroad 12 & 13']),
#  '14': set(['Concession Road 14', 'County Road 14', 'Sideroad 13 & 14']),
#  '15': set(['County Road 15']),
#  '17': set(['Sideroad 16 & 17']),
#  '18': set(['County Road 11 & 18', 'County Road 18']),
#  '19': set(['Sideroad 18 & 19']),
#  '1a': set(['Concession Road 1a']),
#  '2': set(['Concession Road 2', 'County Road 2']),
#  '20': set(['County Road 20']),
#  '202': set(['Wilshire Drive, Suite 202']),
#  '203': set(['North Center Street, Suite 203']),
#  '22': set(['County Road 22']),
#  '223': set(['New US 223']),
#  '23': set(['County Road 23', 'Old US Highway 23']),
#  '3': set(['8th Concession Road, R.R. #3',
#            'Concession Road 3',
#            'Kings Highway 3']),
#  '300': set(['Grand River Ave #300']),
#  '31': set(['County Road  31', 'County Road 31']),
#  '34': set(['County Road 34']),
#  '36': set(['East M 36']),
#  '37': set(['County Road 37']),
#  '4': set(['Concession Road 4']),
#  '40': set(['Green Hill Road Apt 40', 'Highway 40']),
#  '41': set(['County Road 41']),
#  '42': set(['County Road 42']),
#  '46': set(['County Road 46']),
#  '46596': set(['46596']),
#  '5': set(['Concession Road 5']),
#  '50': set(['County Road 50']),
#  '6': set(['Concession Road 6']),
#  '6a': set(['Concession Road 6a']),
#  '7': set(['Concession Road 7', 'Sideroad 6 & 7']),
#  '77': set(['Highway 77']),
#  '8': set(['Concession Road 8', 'County Road 8']),
#  '9': set(['Concession Road 9', 'County Road 9']),
#  'Albuna': set(['Townline  Albuna']),
#  'Alfred': set(['Alfred']),
#  'Alley': set(['Dix Alley']),
#  'Ave': set(['Baldwin Ave',
#              'Dougall Ave',
#              'E. Jefferson Ave',
#              'Edison Ave',
#              'Grand River Ave',
#              'Jackson Ave',
#              'Lincoln Ave',
#              'Little Mack Ave',
#              'Mandalay Ave',
#              'Michigan Ave',
#              'Ouellette Ave',
#              'S Grand Ave',
#              'S Grand River Ave',
#              'Van Dyke Ave',
#              'W Warren Ave',
#              'West Michigan Ave',
#              'Woodward Ave']),
#  'Ave.': set(['Grand River Ave.',
#               'Jefferson Ave.',
#               'North Gratiot Ave.',
#               'W Grand River Ave.']),
#  'B.': set(['Pine Grove Ave, Suite B.']),
#  'Baseline': set(['Baseline']),
#  'Beach': set(['Marentette Beach']),
#  'Belmont': set(['Belmont']),
#  'Bend': set(['Creek Bend', 'Harvest Bend', 'Horseshoe Bend']),
#  'Biddle': set(['Biddle']),
#  'Bluff': set(['Country Bluff']),
#  'Blvd': set(['W Boston Blvd', 'W South Blvd']),
#  'Blvd.': set(['Little River Blvd.',
#                'R Grand Blvd.',
#                'W. Grand Blvd.',
#                'Washington Blvd.']),
#  'Broadway': set(['Broadway']),
#  'Canfield': set(['W. Canfield']),
#  'Caroline': set(['Caroline']),
#  'Cass': set(['Cass']),
#  'Cedarview': set(['Cedarview']),
#  'Center': set(['Renaissance Center']),
#  'Central': set(['Central']),
#  'Centre': set(['Chrysler Centre']),
#  'Chase': set(['Steeple Chase']),
#  'Circle': set(['Barclay Circle',
#                 'Bertram Circle',
#                 'Briarwood Circle',
#                 'Champion Circle',
#                 'Champions Circle',
#                 'Citation Circle',
#                 'Country Circle',
#                 'Cousineau Circle',
#                 'Cram Circle',
#                 'Deepwood Circle',
#                 'Irongate Circle',
#                 'Leslie Circle',
#                 'Lexington Circle',
#                 'Lohr Circle',
#                 'North Hill Circle',
#                 'Osaka Circle',
#                 'Paddock Green Circle',
#                 'Paisley Circle',
#                 'Park Lane Circle',
#                 'Plum Tree Circle',
#                 'Shoreview Circle',
#                 'Vicky Circle',
#                 'Village Circle',
#                 'Wahboose Circle',
#                 'Whisper Creek Circle',
#                 'Winners Circle']),
#  'Coast': set(['Gold Coast']),
#  'Coolidge': set(['W. Coolidge']),
#  'Crescent': set(['Acorn Crescent',
#                   'Alan Crescent',
#                   'Alderbury Crescent',
#                   'Allison Crescent',
#                   'Alta B Crescent',
#                   'Amberly Crescent',
#                   'Ancona Crescent',
#                   'Andrew Crescent',
#                   'Angstrom Crescent',
#                   'Appletree Crescent',
#                   'Aristotle Crescent',
#                   'Ashfield Crescent',
#                   'Ashley Crescent',
#                   'Assiniboine Crescent',
#                   'Astor Crescent',
#                   'Atwater Crescent',
#                   'Aurelia Crescent',
#                   'Azalia Crescent',
#                   'Baker Crescent',
#                   'Barcelona Crescent',
#                   'Barton Crescent',
#                   'Bayberry Crescent',
#                   'Bayfield Crescent',
#                   'Bayswater Crescent',
#                   'Bayview Crescent',
#                   'Beniuk Crescent',
#                   'Beth Crescent',
#                   'Binder Crescent',
#                   'Birchwood Crescent',
#                   'Blackthorn Crescent',
#                   'Blairwood Crescent',
#                   'Bluewater Crescent',
#                   'Border Crescent',
#                   'Boulder Crescent',
#                   'Bramley Crescent',
#                   'Branton Crescent',
#                   'Brenda Crescent',
#                   'Brentwood Crescent',
#                   'Briarwood Crescent',
#                   'Brock Crescent',
#                   'Brookview Crescent',
#                   'Brouillette Crescent',
#                   'Brownlee Crescent',
#                   'Brunelle Crescent',
#                   'Brush Crescent',
#                   'Burbank Crescent',
#                   'Burdick Crescent',
#                   'Cada Crescent',
#                   'Cairns Crescent',
#                   'Cambridge Crescent',
#                   'Canary Crescent',
#                   'Candlewood Crescent',
#                   'Cardinal Crescent',
#                   'Caribou Crescent',
#                   'Carling Crescent',
#                   'Carolina Woods Crescent',
#                   'Cartier Crescent',
#                   'Cedar Crescent',
#                   'Centennial Crescent',
#                   'Champ Crescent',
#                   'Chelsea Crescent',
#                   'Cherrylawn Crescent',
#                   'Chornoby Crescent',
#                   'Christina Crescent',
#                   'Clairwood Crescent',
#                   'Clearview Crescent',
#                   'Clydesdale Crescent',
#                   'Cobblestone Crescent',
#                   'Collier Crescent',
#                   'Community Crescent',
#                   'Cooper Crescent',
#                   'Coram Crescent',
#                   'Cortina Crescent',
#                   'Courtland Crescent',
#                   'Cranbrook Crescent',
#                   'Crozier Crescent',
#                   'Daneila Crescent',
#                   'Darlington Crescent',
#                   'David Crescent',
#                   'Deerview Crescent',
#                   'Diane Crescent',
#                   'Dieppe Crescent',
#                   'Donald Crescent',
#                   'Driftwood Crescent',
#                   'Dunlop Crescent',
#                   'Eagle Crescent',
#                   'Eastgrove Crescent',
#                   'Elizabeth Crescent',
#                   'Elmgate Crescent',
#                   'Elmwood Crescent',
#                   'Elsfield Crescent',
#                   'Emma Maria Crescent',
#                   'Erie Glen Crescent',
#                   'Erindale Crescent',
#                   'Faholo Crescent',
#                   'Fairlane Crescent',
#                   'Fairlea Crescent',
#                   'Fairway Crescent',
#                   'Fasan Crescent',
#                   'Fischer Crescent',
#                   'Forest Hill Crescent',
#                   'Fuller Crescent',
#                   'Funaro Crescent',
#                   'Gardiner Crescent',
#                   'Garvey Crescent',
#                   'Gary Crescent',
#                   'George Crescent',
#                   'Gignac Crescent',
#                   'Giselle Crescent',
#                   'Glenesk Crescent',
#                   'Golfcourse Crescent',
#                   'Golfwood Crescent',
#                   'Granby Crescent',
#                   'Grand View Crescent',
#                   'Greenwood Crescent',
#                   'Gregory Crescent',
#                   'Guildwood Crescent',
#                   'Halo Crescent',
#                   'Halstead Crescent',
#                   'Hanley Crescent',
#                   'Hansen Crescent',
#                   'Harbourne Crescent',
#                   'Hawthorn Crescent',
#                   'Heatherglen Crescent',
#                   'Helen Crescent',
#                   'Helena Crescent',
#                   'Helsinki Crescent',
#                   'Heritage Garden Crescent',
#                   'Hickory Crescent',
#                   'Higgins Crescent',
#                   'Hillview Crescent',
#                   'Holly Crescent',
#                   'Holmes Crescent',
#                   'Hope Crescent',
#                   'Horwood Crescent',
#                   'Hunt Club Crescent',
#                   'Hyatt Crescent',
#                   'Imperial Crescent',
#                   'Innerkip Crescent',
#                   'Jacie Crescent',
#                   'James Crescent',
#                   'Juliet Crescent',
#                   'Kael Crescent',
#                   'Katie Crescent',
#                   'Katrishe Crescent',
#                   'Keating Crescent',
#                   'Kenwood Crescent',
#                   'Kerr Crescent',
#                   'Kingston Crescent',
#                   'Klundert Crescent',
#                   'Lake Crescent',
#                   'Lawson Crescent',
#                   'Lemonwood Crescent',
#                   'Lepain Crescent',
#                   'Linda Crescent',
#                   'Littler Crescent',
#                   'Lombardy Crescent',
#                   'Lonsdale Crescent',
#                   'Lovell Crescent',
#                   'Lucy Crescent',
#                   'Lydia Crescent',
#                   'Lynngrove Crescent',
#                   'Malden Crescent',
#                   'Manitou Crescent',
#                   'Maple Leaf Crescent',
#                   'Maplewood Crescent',
#                   'Marie Crescent',
#                   'Marina Grove Crescent',
#                   'Mark Crescent',
#                   'Marlene Crescent',
#                   'Marlo Crescent',
#                   'Martin Crescent',
#                   'Masotti Crescent',
#                   'Massimo Crescent',
#                   'Matthew Crescent',
#                   'Mayrand Crescent',
#                   'McMahon Crescent',
#                   'Meadowland Crescent',
#                   'Meander Crescent',
#                   'Mei Lin Crescent',
#                   'Michael Crescent',
#                   'Mickaila Crescent',
#                   'Midfield Crescent',
#                   'Mill Creek Crescent',
#                   'Mill Crescent',
#                   'Mitchell Crescent',
#                   'Moceri Crescent',
#                   'Molnar Crescent',
#                   'Montego Bay Crescent',
#                   'Montgomery Crescent',
#                   'Mount Pleasant Crescent',
#                   'Mount Sinai Crescent',
#                   'Mountbatten Crescent',
#                   'Mousseau Crescent',
#                   'Murray Crescent',
#                   'Naples Crescent',
#                   'Osborn Crescent',
#                   'Palms Crescent',
#                   'Park Crescent',
#                   'Parkdale Crescent',
#                   'Parkland Crescent',
#                   'Patrick Crescent',
#                   'Paul Crescent',
#                   'Paula Crescent',
#                   'Peach Blossom Crescent',
#                   'Philip Crescent',
#                   'Pinetree Crescent',
#                   'Pineview Crescent',
#                   'Pinewood Crescent',
#                   'Providence Crescent',
#                   'Queens Hill Crescent',
#                   'Red Oak Crescent',
#                   'Redwood Crescent',
#                   'Regency Crescent',
#                   'Remo Crescent',
#                   'Robin Crescent',
#                   'Roxbury Crescent',
#                   'Royal Crescent',
#                   'Rushwood Crescent',
#                   'Sand Pebble Crescent',
#                   'Satinwood Crescent',
#                   'Seymour Crescent',
#                   'Shadetree Crescent',
#                   'Shady Springs Crescent',
#                   'Shelley Crescent',
#                   'Shenandoah Crescent',
#                   'Sherway Crescent',
#                   'Simard Crescent',
#                   'Smith Crescent',
#                   'Socrates Crescent',
#                   'Solar Crescent',
#                   'Sorge Crescent',
#                   'South Wind Crescent',
#                   'Southwest Crescent',
#                   'Spaco Crescent',
#                   'St Agnes Crescent',
#                   'St Luke Crescent',
#                   'St Martin Crescent',
#                   'St Thomas Crescent',
#                   'St. Thomas Crescent',
#                   'Sterling Crescent',
#                   'Stewart Crescent',
#                   'Stoneybrook Crescent',
#                   'Sugarwood Crescent',
#                   'Sumach Crescent',
#                   'Sunnybrook Crescent',
#                   'Sylvano Crescent',
#                   'Sylvestre Crescent',
#                   'Taylor Crescent',
#                   'Teedie Crescent',
#                   'Templeton Crescent',
#                   'Tennessee Crescent',
#                   'Thompson Crescent',
#                   'Thorn Ridge Crescent',
#                   'Thornberry Crescent',
#                   'Timber Bay Crescent',
#                   'Tracey Crescent',
#                   'Troup Crescent',
#                   'Tumbleweed Crescent',
#                   'Turner Crescent',
#                   'Turnhout Crescent',
#                   'Tuscany Crescent',
#                   'Van Crescent',
#                   'Vernon Crescent',
#                   'Villa Paradiso Crescent',
#                   'Wawa Crescent',
#                   'Whistler Crescent',
#                   'Whitefish Crescent',
#                   'Whites Crescent',
#                   'Wildberry Crescent',
#                   'Willow Crescent',
#                   'Willowdale Crescent',
#                   'Winston Crescent',
#                   'Woodland Crescent',
#                   'Woodlawn Crescent',
#                   'Woodmont Crescent',
#                   'Woodward Crescent']),
#  'Ct': set(['Armstrong Ct', 'Marquette Ct', 'Stone Wood Ct', 'Victoria Ct']),
#  'Davison': set(['Davison']),
#  'Degurse': set(['Degurse']),
#  'Dequindre': set(['Dequindre']),
#  'Detroit': set(['Mt Elliott St, Detroit']),
#  'Dr': set(['Corporate Dr',
#             'E. Fisher Service Dr',
#             'E. Huron River Dr',
#             'Essex Dr',
#             'Shoreline Dr',
#             'Sierra Dr',
#             'Tallman Dr',
#             'Town Center Dr']),
#  'Dr.': set(['Old Milford Farms Dr.', 'Westchester Dr.']),
#  'Dyke': set(['Van Dyke']),
#  'E': set(['Tecumseh Rd E']),
#  'East': set(['Adams Avenue East',
#               'Brien Avenue East',
#               'Cabana Road East',
#               'Cabela Boulevard East',
#               'Cameron Sideroad East',
#               'Centre Street East',
#               'Chatham Street East',
#               'Clark Street East',
#               'Concession Road  2  East',
#               'Concession Road  3  East',
#               'Concession Road 3 East',
#               'Concession Road 4 East',
#               'Concession Road 5 East',
#               'Concession Road 6 East',
#               'Concession Road 8 East',
#               'County Road 14 East',
#               'Errol Road East',
#               'Fairview Avenue East',
#               'Grand Marais Road East',
#               'Kennedy Drive East',
#               'King Street East',
#               'Lafayette Street East',
#               'Maidstone Avenue East',
#               'Main Street East',
#               'Marlborough Street East',
#               'McMillen Parkway East',
#               'Medora Avenue East',
#               'Mill Street East',
#               'Montage East',
#               'Normandy Court East',
#               'North Service Road East',
#               'Oak Manor Court East',
#               'Oak Street East',
#               'Park Street East',
#               'Pearl Street East',
#               'Phillip Street East',
#               'Pinecrest Drive East',
#               'Riverside Drive East',
#               'Roseland Drive East',
#               'Seacliff Drive East',
#               'Sinasac Avenue East',
#               'South Boulevard East',
#               'Talbot Road East',
#               'Talbot Street East',
#               'Tecumseh Road East',
#               'Tudor Close East',
#               'Tyrie Drive East',
#               'University Avenue East',
#               'Woodland Drive East',
#               'Wyandotte Street East']),
#  'Eisenhower': set(['West Eisenhower']),
#  'Equestrian': set(['Equestrian']),
#  'Estates': set(['Eastgate Estates']),
#  'Evaline': set(['Evaline']),
#  'Expressway': set(['Southfield Expressway']),
#  'Fair': set(['West State Fair']),
#  'Fenton': set(['Fenton']),
#  'Forest': set(['South Forest']),
#  'Gardens': set(['Lexham Gardens', 'Marvin Gardens', 'St Clair Gardens']),
#  'Garfield': set(['Garfield']),
#  'Glengary': set(['Glengary']),
#  'Gosfield': set(['Townline East Gosfield', 'Townline West Gosfield']),
#  'Gratiot': set(['Gratiot']),
#  'Greenfield': set(['Greenfield']),
#  'Grove': set(['Mount Olive Grove',
#                'Orchard Grove',
#                'Shorain Grove',
#                'Wigle Grove']),
#  'Hamlin': set(['E Hamlin']),
#  'Heights': set(['Washington Heights']),
#  'Highway': set(['Coolidge Highway',
#                  'Dix Highway',
#                  'Dixie Highway',
#                  'Ford Highway',
#                  'Fred W. Moore Highway',
#                  'Groesbeck Highway',
#                  'Hane Highway',
#                  'North Ballenger Highway',
#                  'North Dixie Highway',
#                  'Northeastern Highway',
#                  'Northwestern Highway',
#                  'Old US-12 Highway',
#                  'Sand Creek Highway',
#                  'Schaefer Highway',
#                  'South Ballenger Highway',
#                  'South Dixie Highway',
#                  'South Dort Highway',
#                  'South Industrial Highway',
#                  'Stephenson Highway',
#                  'Tecumseh-Clinton Highway',
#                  'West Vernor Highway',
#                  'Wolf Creek Highway']),
#  'Hill': set(['Ferry Dock Hill']),
#  'Hwy': set(['Coolidge Hwy', 'Stephenson Hwy']),
#  'Jefferson': set(['East Jefferson']),
#  'Kinloch': set(['Kinloch']),
#  'Labbe': set(['Rue Labbe']),
#  'Lafayette': set(['Avenue de Lafayette']),
#  'Lake': set(['E Long Lake', 'East Square Lake']),
#  'Leathorne': set(['Leathorne']),
#  'Lichfield': set(['Lichfield']),
#  'Lincoln': set(['West Lincoln']),
#  'Line': set(['1st Concession Line',
#               '2nd Concession Line',
#               '3rd Concession Line',
#               '4th Concession Line',
#               '5th Concession Line',
#               '6th Concession Line',
#               'Angler Line',
#               'Bait Line',
#               'Bassette Line',
#               'Bay Line',
#               'Bentpath Line',
#               'Bickford Line',
#               'Bills Line',
#               'Bluewater Line',
#               'Bluff Line',
#               'Cast Line',
#               'Charlemont Line',
#               'Clarke Private Line',
#               'Courtright Line',
#               'Detroit Line',
#               'Elbow Line',
#               'Erie Private Line',
#               'French Line',
#               'Goodreau Line',
#               'Gray Line',
#               'Gregory Line',
#               'Haven Line',
#               'Heritage Line',
#               'Herman Line',
#               'Heron Line',
#               'Holt Line',
#               'Hornick Line',
#               'Kemp Line',
#               'Kerr Line',
#               'La Salle Line',
#               'Lambton Line',
#               'Langstaff Line',
#               'Mallard Line',
#               'Marsh Line',
#               'Meadowvale Line',
#               'Middle Line',
#               'Middleton Line',
#               'Moore Line',
#               'Mud Creek Line',
#               'Ocean Private Line',
#               'Oil Springs Line',
#               'Otter Line',
#               'Petrolia Line',
#               'Pointe Line',
#               'Quinn Line',
#               'Rivard Line',
#               'Robin Line',
#               'Rokeby Line',
#               'Rosedale Line',
#               'Seys Line',
#               'Smith Line',
#               'St Anne Line',
#               'St Philippes Line',
#               'Stanley Line',
#               'Sterling Line',
#               'Stewart Line',
#               'Swan Line',
#               'Terrys Line',
#               'Tideswell Private Line',
#               'Tilton Private Line',
#               'Tulloch Line',
#               'Ward Line',
#               'West Bentpath Line',
#               'West French Line',
#               'West Holt Line',
#               'West Lambton Line',
#               'West Pointe Line',
#               'West Smith Line',
#               'West Ward Line',
#               'West White Line',
#               'West Whitebread Line',
#               'West Wilkesport Line',
#               'White Line',
#               'Whitebread Line',
#               'Whites Line',
#               'Wilkesport Line',
#               'William Lewis Line',
#               'Wren Line']),
#  'Lothrop': set(['Lothrop']),
#  'Malden': set(['Townline Road Colchester South Malden']),
#  'Mall': set(['Ferry Mall', 'Gullen Mall', 'Reuther Mall', 'Williams Mall']),
#  'Maple': set(['35275 Silver Maple']),
#  'McNichols': set(['West McNichols']),
#  'Middlebelt': set(['Middlebelt']),
#  'Mile': set(['6 Mile']),
#  'N': set(['Interpark Dr N']),
#  'North': set(['Alice Street North',
#                'Arthur Street North',
#                'Balaclava Street North',
#                'Brock Street North',
#                'Cherry Lane North',
#                'Christina Street North',
#                'College Avenue North',
#                'Concession Road 4 North',
#                'Concession Road 5 North',
#                'Concession Road 6 North',
#                'Delmer Crescent North',
#                'Division Road North',
#                'Division Street North',
#                'Duck Lake Road North',
#                'East Street North',
#                'East. Street North',
#                'Erie Street North',
#                'Euphemia Street North',
#                'Floralview Drive North',
#                'Forsyth Street North',
#                'Front Road North',
#                'Front Street North',
#                'Hanlan Street North',
#                'Indian Road North',
#                'Justras Drive North',
#                'Laird Avenue North',
#                'Lakeside Boulevard North',
#                'Lambeth Court North',
#                'Little Street North',
#                'MacKenzie Street North',
#                'Main Street North',
#                'Milne Street North',
#                'Mitton Street North',
#                'Palmerston Street North',
#                'Prince Albert Street North',
#                'Ridgeview Place North',
#                'River Road North',
#                'Russell Street North',
#                'Sandwich Street North',
#                'Secord Street North',
#                'South Talbot Road North',
#                'Spruce Street North',
#                'Talbot Street North',
#                'Townline Road Malden Colchester North',
#                'Victoria Avenue North',
#                'Victoria Street North',
#                'Vidal Street North',
#                'Villa Maria Boulevard North',
#                'Village Circle North',
#                'Walnut Avenue North',
#                'Wilder Drive North']),
#  'Olympia': set(['Olympia']),
#  'Orland': set(['Orland']),
#  'Orndorf': set(['Charles H Orndorf']),
#  'Overland': set(['Overland']),
#  'Park': set(['Astor Park',
#               'Cotterie Park',
#               'Dorset Park',
#               'Estate Park',
#               'Highbury Park',
#               'Joel Park',
#               'Pineway Park',
#               'Trillium Park']),
#  'Pembroke': set(['Pembroke']),
#  'Pkwy': set(['Metropolitan Pkwy', 'Northfieild Pkwy', 'Northfield Pkwy']),
#  'Pl': set(['Nicolet Pl', 'Orchard Hill Pl']),
#  'Pl.': set(['Cottage Pl.', 'Edmund Pl.']),
#  'Plaza': set(['Hurley Plaza', 'Jackson Plaza']),
#  'Point': set(['Hingle Point']),
#  'Poplar': set(['Poplar']),
#  'Quincy': set(['Quincy']),
#  'Railway': set(['Canada South Railway']),
#  'Rd': set(['21 Mile Rd',
#             '32625 Industrial Rd',
#             '396 John R Rd',
#             '5 Mile Rd',
#             'Arsenal Rd',
#             'Auburn Rd',
#             'Belleville Rd',
#             'Bluebush Rd',
#             'Clark Rd',
#             'Coolidge Rd',
#             'Crooks Rd',
#             'Dequindre Rd',
#             'E 11 Mile Rd',
#             'E 15 Mile Rd',
#             'E 9 Mile Rd',
#             'E Big Beaver Rd',
#             'E Commerce Rd',
#             'E Long Lake Rd',
#             'E Maple Rd',
#             'East Dunbar Rd',
#             'Fisher Rd',
#             'Ford Rd',
#             'Haggerty Rd',
#             'Hall Rd',
#             'Hill Rd',
#             'Jackson Rd',
#             'John R Rd',
#             'Livernois Rd',
#             'Loop Rd',
#             'Mabley Hill Rd',
#             'N Ann Arbor Rd',
#             'N Maple Rd',
#             'N Squirrel Rd',
#             'Orchard Lake Rd',
#             'Rochester Rd',
#             'Ryan Rd',
#             'S Haggerty Rd',
#             'Sashabaw Rd',
#             'Shimmons Rd',
#             'Southfield Rd',
#             'Sterns Rd',
#             'Telegraph Rd',
#             'W 26 Mile Rd',
#             'W 7 Mile Rd',
#             'W Big Beaver Rd',
#             'W Long Lake Rd',
#             'W Maple Rd',
#             'W. Maple Rd',
#             'West Rd',
#             'Wixom Rd']),
#  'Rd.': set(['Consear Rd.',
#              'E 12 Mile Rd.',
#              'E. Tienken Rd.',
#              'Lauzon Rd.',
#              'Sashabaw Rd.']),
#  'River': set(['East Grand River',
#                'Grand River',
#                'W Grand River',
#                'W. Grand River']),
#  'Rochester': set(['Townline Road Rochester']),
#  'Rose': set(['St. Rose']),
#  'Row': set(['Maple Row']),
#  'Run': set(['Ruggles Run']),
#  'Saginaw': set(['Saginaw']),
#  'Second': set(['Second']),
#  'Service': set(['Edsel Ford Fwy I- 94 Service']),
#  'Sheldon': set(['Sheldon']),
#  'Sideroad': set(['Batton Sideroad',
#                   'Beaudoin Sideroad',
#                   'Briton Sideroad',
#                   'Brush Sideroad',
#                   'Comber Sideroad',
#                   'Cottam Sideroad',
#                   'Coulter Sideroad',
#                   'Ellis Sideroad',
#                   'Ferris Sideroad',
#                   'Gesto Sideroad',
#                   'Gracey Sideroad',
#                   'Graham Sideroad',
#                   'Hopgood Sideroad',
#                   'Hyland Sideroad',
#                   'Inman Sideroad',
#                   'Lowes Sideroad',
#                   'Marsh Sideroad',
#                   'McCain Sideroad',
#                   'Middle Sideroad',
#                   'Mole Sideroad',
#                   'Naylor Sideroad',
#                   'North Sideroad',
#                   "O'brien Sideroad",
#                   'Olinda Sideroad',
#                   'Richardson Sideroad',
#                   'Sexton Sideroad',
#                   'Trembley Sideroad',
#                   'Upcott Sideroad',
#                   'Walker Sideroad',
#                   'Wilson Sideroad']),
#  'South': set(['Alice Street South',
#                'Arthur Street South',
#                'Balaclava Street South',
#                'Brock Street South',
#                'Cherry Lane South',
#                'Christina Street South',
#                'College Avenue South',
#                'Concession Road 4 South',
#                'Concession Road 5 South',
#                'Concession Road 6 South',
#                'Delmer Crescent South',
#                'Division Street South',
#                'East Street South',
#                'Equestrian South',
#                'Erie Street South',
#                'Euphemia Street South',
#                'Floralview Drive South',
#                'Forsyth Street South',
#                'Fort Street South',
#                'Front Road South',
#                'Front Street South',
#                'Hanlan Street South',
#                'Indian Road South',
#                'Justras Drive South',
#                'Laird Avenue South',
#                'Lambeth Court South',
#                'Little Street South',
#                'MacKenzie Street South',
#                'Main Street South',
#                'Milne Street South',
#                'Mitton Street South',
#                'Palmerston Street South',
#                'Prince Albert Street South',
#                'Queen Street South',
#                'Ridgeview Place South',
#                'Roseland Drive South',
#                'Russell Street South',
#                'Sandwich Street South',
#                'Secord Street South',
#                'South Talbot Road South',
#                'Spruce Street South',
#                'Talbot Street South',
#                'Townline Road Malden Colchester South',
#                'Victoria Avenue South',
#                'Victoria Street South',
#                'Vidal Street South',
#                'Villa Maria Boulevard South',
#                'Village Circle South',
#                'Walnut Avenue South',
#                'Walnut Street South',
#                'Wilder Drive South']),
#  'St': set(['Alfred St',
#             'Barrington St',
#             'Broadway St',
#             'Burroughs St',
#             'Dennison St',
#             'E. Nevada St',
#             'Fort St',
#             'Lyndon St',
#             'Main St',
#             'S Main St',
#             'W Congress St',
#             'W Fort St']),
#  'St.': set(['Alfred St.',
#              'Brush St.',
#              'Church St.',
#              'Griswold St.',
#              'Grove St.',
#              'Jerome St.',
#              'N. Main St.',
#              'Rockwood St.',
#              'Vinewood St.']),
#  'Starkweather': set(['Starkweather']),
#  'Sugarbush': set(['Sugarbush']),
#  'Sylvester': set(['Sylvester']),
#  'Tecumseh': set(['Tecumseh']),
#  'Triangle': set(['Citation Triangle']),
#  'US-23': set(['Old US-23']),
#  'Union': set(['Main St Union']),
#  'Village': set(['Country Village']),
#  'W': set(['University Ave W']),
#  'W.': set(['Pitt Street W.', 'Riverside Drive W.', 'Wyandotte St. W.']),
#  'Wagner': set(['29217 Wagner']),
#  'Washington': set(['Washington']),
#  'Way': set(['Carrot Way',
#              'Catalpa Way',
#              'Coral Way',
#              'Country Way',
#              'Cumberland Way',
#              'Enterprise Way',
#              'Essex Way',
#              'George Kennedy Way',
#              'Grantham Way',
#              'Hacienda Way',
#              'Heatherstone Way',
#              'Jessica Way',
#              'Kenwick Way',
#              'Lyndon Way',
#              'Mannheim Way',
#              'Marjories Way',
#              'Northfield Way',
#              'Ravenya Way',
#              'Rowellas Way',
#              'Sandy Brook Way',
#              'Stonebridge Way',
#              'Thurso Way',
#              'Victors Way',
#              'Walstedt Way']),
#  'West': set(['7 Mile Road West',
#               'Adams Avenue West',
#               'Ann Arbor Road West',
#               'Brien Avenue West',
#               'Cameron Sideroad West',
#               'Centre Street West',
#               'Clark Street West',
#               'Concession Road  2  West',
#               'Concession Road 2 West',
#               'Concession Road 3 West',
#               'Concession Road 4 West',
#               'Concession Road 5 West',
#               'Concession Road 6 West',
#               'Concession Road 7 West',
#               'Concession Road 8 West',
#               'County Road 27 West',
#               'Dredge Cut Road West',
#               'Errol Road West',
#               'Fairview Avenue West',
#               'Fort Street West',
#               'Front Road West',
#               'Guthrie Drive West',
#               'King Street West',
#               'Maidstone Avenue West',
#               'Main Street West',
#               'Marlborough Street West',
#               'McMillen Parkway West',
#               'Medora Avenue West',
#               'Mill Street West',
#               'Montage West',
#               'Normandy Court West',
#               'Oak Manor Court West',
#               'Oak Street West',
#               'Park Street West',
#               'Pearl Street West',
#               'Phillip Street West',
#               'Pitt Street West',
#               'Renaissance Drive West',
#               'Roseland Drive West',
#               'Seacliff Drive West',
#               'Sinasac Avenue West',
#               'Talbot Road West',
#               'Talbot Street West',
#               'Tudor Close West',
#               'Tyrie Drive West',
#               'University Avenue West',
#               'Wellington Avenue West']),
#  'Woods': set(['Carolina Woods']),
#  'Woodward': set(['Woodward']),
#  'Wynd': set(['Shorehaven Wynd']),
#  'Wyoming': set(['Wyoming']),
#  'Yemans': set(['Yemans']),
#  'ave': set(['bordeaux ave']),
#  'il': set(['E 14 st lockport il']),
#  'mile': set(['6 mile']),
#  'road': set(['Carpenter road', 'Packard road']),
#  'way': set(['Lambeth way'])}
# Yemans => Yemans
# Baseline => Baseline
# Edsel Ford Fwy I- 94 Service => Edsel Ford Fwy I- 94 Service
# Main St Union => Main St Union
# Orland => Orland
# Wyoming => Wyoming
# Washington Heights => Washington Heights
# Shimmons Rd => Shimmons Road
# N Squirrel Rd => N Squirrel Road
# E Long Lake Rd => E Long Lake Road
# John R Rd => John R Road
# W 26 Mile Rd => W 26 Mile Road
# E Big Beaver Rd => E Big Beaver Road
# W Maple Rd => W Maple Road
# Belleville Rd => Belleville Road
# Ryan Rd => Ryan Road
# S Haggerty Rd => S Haggerty Road
# E 11 Mile Rd => E 11 Mile Road
# Mabley Hill Rd => Mabley Hill Road
# Southfield Rd => Southfield Road
# Fisher Rd => Fisher Road
# Auburn Rd => Auburn Road
# E Maple Rd => E Maple Road
# Orchard Lake Rd => Orchard Lake Road
# 21 Mile Rd => 21 Mile Road
# Ford Rd => Ford Road
# 396 John R Rd => 396 John R Road
# East Dunbar Rd => East Dunbar Road
# 5 Mile Rd => 5 Mile Road
# Telegraph Rd => Telegraph Road
# West Rd => West Road
# W Big Beaver Rd => W Big Beaver Road
# Livernois Rd => Livernois Road
# Haggerty Rd => Haggerty Road
# Bluebush Rd => Bluebush Road
# W. Maple Rd => W. Maple Road
# Crooks Rd => Crooks Road
# Dequindre Rd => Dequindre Road
# 32625 Industrial Rd => 32625 Industrial Road
# N Ann Arbor Rd => N Ann Arbor Road
# Sashabaw Rd => Sashabaw Road
# Hill Rd => Hill Road
# Wixom Rd => Wixom Road
# Sterns Rd => Sterns Road
# N Maple Rd => N Maple Road
# Loop Rd => Loop Road
# E 9 Mile Rd => E 9 Mile Road
# E Commerce Rd => E Commerce Road
# W 7 Mile Rd => W 7 Mile Road
# E 15 Mile Rd => E 15 Mile Road
# Coolidge Rd => Coolidge Road
# Arsenal Rd => Arsenal Road
# Clark Rd => Clark Road
# Hall Rd => Hall Road
# W Long Lake Rd => W Long Lake Road
# Rochester Rd => Rochester Road
# Jackson Rd => Jackson Road
# 6 mile => 6 mile
# Ferry Dock Hill => Ferry Dock Hill
# W. Canfield => W. Canfield
# Cedarview => Cedarview
# County Road 20 => County Road 20
# Sheldon => Sheldon
# County Road 22 => County Road 22
# Old US Highway 23 => Old US Highway 23
# County Road 23 => County Road 23
# Lothrop => Lothrop
# Concession Road 4 => Concession Road 4
# County Road 8 => County Road 8
# Concession Road 8 => Concession Road 8
# Pembroke => Pembroke
# Saginaw => Saginaw
# Metropolitan Pkwy => Metropolitan Parkway
# Northfield Pkwy => Northfield Parkway
# Northfieild Pkwy => Northfieild Parkway
# Poplar => Poplar
# W. Grand River => W. Grand River
# East Grand River => East Grand River
# W Grand River => W Grand River
# Grand River => Grand River
# Greenfield => Greenfield
# Olympia => Olympia
# Degurse => Degurse
# Riverside Drive W. => Riverside Drive West
# Wyandotte St. W. => Westandotte St. West
# Pitt Street W. => Pitt Street West
# Pine Grove Ave, Suite B. => Pine Grove Ave, Suite B.
# Kinloch => Kinloch
# Washington => Washington
# County Road 50 => County Road 50
# Shorehaven Wynd => Shorehaven Wynd
# Sugarbush => Sugarbush
# 6 Mile => 6 Mile
# Townline  Albuna => Townline  Albuna
# Woodward => Woodward
# Broadway => Broadway
# Avenue de Lafayette => Avenue de Lafayette
# Steeple Chase => Steeple Chase
# Townline Road Rochester => Townline Road Rochester
# Concession Road 3 West => Concession Road 3 West
# Tyrie Drive West => Tyrie Drive West
# Roseland Drive West => Roseland Drive West
# Marlborough Street West => Marlborough Street West
# Park Street West => Park Street West
# County Road 27 West => County Road 27 West
# Brien Avenue West => Brien Avenue West
# Mill Street West => Mill Street West
# Concession Road 2 West => Concession Road 2 West
# Centre Street West => Centre Street West
# Dredge Cut Road West => Dredge Cut Road West
# Guthrie Drive West => Guthrie Drive West
# Front Road West => Front Road West
# Tudor Close West => Tudor Close West
# Maidstone Avenue West => Maidstone Avenue West
# Cameron Sideroad West => Cameron Sideroad West
# Main Street West => Main Street West
# Concession Road 5 West => Concession Road 5 West
# Medora Avenue West => Medora Avenue West
# Concession Road 7 West => Concession Road 7 West
# Concession Road 6 West => Concession Road 6 West
# Clark Street West => Clark Street West
# Ann Arbor Road West => Ann Arbor Road West
# King Street West => King Street West
# Concession Road  2  West => Concession Road  2  West
# Montage West => Montage West
# Talbot Street West => Talbot Street West
# Oak Street West => Oak Street West
# Wellington Avenue West => Wellington Avenue West
# Fort Street West => Fort Street West
# Adams Avenue West => Adams Avenue West
# University Avenue West => University Avenue West
# Fairview Avenue West => Fairview Avenue West
# Normandy Court West => Normandy Court West
# Sinasac Avenue West => Sinasac Avenue West
# 7 Mile Road West => 7 Mile Road West
# Oak Manor Court West => Oak Manor Court West
# Pitt Street West => Pitt Street West
# Phillip Street West => Phillip Street West
# Concession Road 8 West => Concession Road 8 West
# McMillen Parkway West => McMillen Parkway West
# Renaissance Drive West => Renaissance Drive West
# Pearl Street West => Pearl Street West
# Errol Road West => Errol Road West
# Concession Road 4 West => Concession Road 4 West
# Talbot Road West => Talbot Road West
# Seacliff Drive West => Seacliff Drive West
# Townline West Gosfield => Townline West Gosfield
# Townline East Gosfield => Townline East Gosfield
# East Jefferson => East Jefferson
# Dix Alley => Dix Alley
# Alfred => Alfred
# Old Milford Farms Dr. => Old Milford Farms Drive
# Westchester Dr. => Westchester Drive
# Central => Central
# Shoreview Circle => Shoreview Circle
# Lexington Circle => Lexington Circle
# Bertram Circle => Bertram Circle
# Deepwood Circle => Deepwood Circle
# Cousineau Circle => Cousineau Circle
# Lohr Circle => Lohr Circle
# Paddock Green Circle => Paddock Green Circle
# North Hill Circle => North Hill Circle
# Cram Circle => Cram Circle
# Country Circle => Country Circle
# Irongate Circle => Irongate Circle
# Paisley Circle => Paisley Circle
# Barclay Circle => Barclay Circle
# Champion Circle => Champion Circle
# Vicky Circle => Vicky Circle
# Wahboose Circle => Wahboose Circle
# Whisper Creek Circle => Whisper Creek Circle
# Briarwood Circle => Briarwood Circle
# Champions Circle => Champions Circle
# Village Circle => Village Circle
# Leslie Circle => Leslie Circle
# Winners Circle => Winners Circle
# Plum Tree Circle => Plum Tree Circle
# Park Lane Circle => Park Lane Circle
# Osaka Circle => Osaka Circle
# Citation Circle => Citation Circle
# Park Street East => Park Street East
# Kennedy Drive East => Kennedy Drive East
# King Street East => King Street East
# Montage East => Montage East
# Maidstone Avenue East => Maidstone Avenue East
# Woodland Drive East => Woodland Drive East
# Cabela Boulevard East => Cabela Boulevard East
# Talbot Road East => Talbot Road East
# Concession Road 3 East => Concession Road 3 East
# Concession Road 5 East => Concession Road 5 East
# Sinasac Avenue East => Sinasac Avenue East
# Marlborough Street East => Marlborough Street East
# Concession Road 8 East => Concession Road 8 East
# Adams Avenue East => Adams Avenue East
# Grand Marais Road East => Grand Marais Road East
# Concession Road  3  East => Concession Road  3  East
# University Avenue East => University Avenue East
# Pinecrest Drive East => Pinecrest Drive East
# Pearl Street East => Pearl Street East
# Concession Road 6 East => Concession Road 6 East
# Tyrie Drive East => Tyrie Drive East
# Tudor Close East => Tudor Close East
# Cameron Sideroad East => Cameron Sideroad East
# Normandy Court East => Normandy Court East
# Fairview Avenue East => Fairview Avenue East
# Errol Road East => Errol Road East
# Oak Manor Court East => Oak Manor Court East
# Wyandotte Street East => Wyandotte Street East
# Concession Road 4 East => Concession Road 4 East
# South Boulevard East => South Boulevard East
# Seacliff Drive East => Seacliff Drive East
# Medora Avenue East => Medora Avenue East
# Main Street East => Main Street East
# McMillen Parkway East => McMillen Parkway East
# Cabana Road East => Cabana Road East
# Chatham Street East => Chatham Street East
# North Service Road East => North Service Road East
# Brien Avenue East => Brien Avenue East
# County Road 14 East => County Road 14 East
# Concession Road  2  East => Concession Road  2  East
# Mill Street East => Mill Street East
# Centre Street East => Centre Street East
# Riverside Drive East => Riverside Drive East
# Lafayette Street East => Lafayette Street East
# Roseland Drive East => Roseland Drive East
# Oak Street East => Oak Street East
# Tecumseh Road East => Tecumseh Road East
# Clark Street East => Clark Street East
# Talbot Street East => Talbot Street East
# Phillip Street East => Phillip Street East
# Nicolet Pl => Nicolet Place
# Orchard Hill Pl => Orchard Hill Place
# Second => Second
# Ruggles Run => Ruggles Run
# St. Rose => St. Rose
# Tecumseh => Tecumseh
# Cotterie Park => Cotterie Park
# Estate Park => Estate Park
# Highbury Park => Highbury Park
# Trillium Park => Trillium Park
# Pineway Park => Pineway Park
# Dorset Park => Dorset Park
# Joel Park => Joel Park
# Astor Park => Astor Park
# Biddle => Biddle
# Grand River Ave #300 => Grand River Ave #300
# Concession Road 3 => Concession Road 3
# Kings Highway 3 => Kings Highway 3
# 8th Concession Road, R.R. #3 => 8th Concession Road, R.R. #3
# Sideroad 6 & 7 => Sideroad 6 & 7
# Concession Road 7 => Concession Road 7
# Terrys Line => Terrys Line
# Quinn Line => Quinn Line
# Langstaff Line => Langstaff Line
# Seys Line => Seys Line
# Ward Line => Ward Line
# Bentpath Line => Bentpath Line
# 5th Concession Line => 5th Concession Line
# Petrolia Line => Petrolia Line
# Courtright Line => Courtright Line
# Mud Creek Line => Mud Creek Line
# Tideswell Private Line => Tideswell Private Line
# French Line => French Line
# Bay Line => Bay Line
# Charlemont Line => Charlemont Line
# Hornick Line => Hornick Line
# Wren Line => Wren Line
# La Salle Line => La Salle Line
# Whites Line => Whites Line
# West Holt Line => West Holt Line
# William Lewis Line => William Lewis Line
# Rivard Line => Rivard Line
# Haven Line => Haven Line
# Heritage Line => Heritage Line
# 6th Concession Line => 6th Concession Line
# West Smith Line => West Smith Line
# Kemp Line => Kemp Line
# 3rd Concession Line => 3rd Concession Line
# Erie Private Line => Erie Private Line
# Wilkesport Line => Wilkesport Line
# Mallard Line => Mallard Line
# Angler Line => Angler Line
# 4th Concession Line => 4th Concession Line
# White Line => White Line
# 1st Concession Line => 1st Concession Line
# Smith Line => Smith Line
# Moore Line => Moore Line
# Bait Line => Bait Line
# West Bentpath Line => West Bentpath Line
# Oil Springs Line => Oil Springs Line
# Kerr Line => Kerr Line
# West White Line => West White Line
# Stanley Line => Stanley Line
# Bluff Line => Bluff Line
# Bassette Line => Bassette Line
# Middle Line => Middle Line
# Rokeby Line => Rokeby Line
# St Philippes Line => St Philippes Line
# Ocean Private Line => Ocean Private Line
# Marsh Line => Marsh Line
# Tilton Private Line => Tilton Private Line
# West Pointe Line => West Pointe Line
# Holt Line => Holt Line
# West Lambton Line => West Lambton Line
# St Anne Line => St Anne Line
# Meadowvale Line => Meadowvale Line
# Middleton Line => Middleton Line
# West Wilkesport Line => West Wilkesport Line
# Herman Line => Herman Line
# Goodreau Line => Goodreau Line
# West French Line => West French Line
# Gray Line => Gray Line
# Bickford Line => Bickford Line
# Clarke Private Line => Clarke Private Line
# Lambton Line => Lambton Line
# Gregory Line => Gregory Line
# Rosedale Line => Rosedale Line
# Bills Line => Bills Line
# Elbow Line => Elbow Line
# Whitebread Line => Whitebread Line
# 2nd Concession Line => 2nd Concession Line
# Tulloch Line => Tulloch Line
# Sterling Line => Sterling Line
# Otter Line => Otter Line
# Swan Line => Swan Line
# West Ward Line => West Ward Line
# Pointe Line => Pointe Line
# Detroit Line => Detroit Line
# Heron Line => Heron Line
# Bluewater Line => Bluewater Line
# Stewart Line => Stewart Line
# Robin Line => Robin Line
# West Whitebread Line => West Whitebread Line
# Cast Line => Cast Line
# Jefferson Ave. => Jefferson Avenue
# W Grand River Ave. => W Grand River Avenue
# Grand River Ave. => Grand River Avenue
# North Gratiot Ave. => North Gratiot Avenue
# Orchard Grove => Orchard Grove
# Mount Olive Grove => Mount Olive Grove
# Wigle Grove => Wigle Grove
# Shorain Grove => Shorain Grove
# Sylvester => Sylvester
# Hurley Plaza => Hurley Plaza
# Jackson Plaza => Jackson Plaza
# Ferry Mall => Ferry Mall
# Williams Mall => Williams Mall
# Gullen Mall => Gullen Mall
# Reuther Mall => Reuther Mall
# University Ave W => University Ave West
# Fenton => Fenton
# Orchard Hill Place, Suite 100 => Orchard Hill Place, Suite 100
# Little River Blvd. => Little River Boulevard
# Washington Blvd. => Washington Boulevard
# W. Grand Blvd. => W. Grand Boulevard
# R Grand Blvd. => R Grand Boulevard
# West State Fair => West State Fair
# Hingle Point => Hingle Point
# Overland => Overland
# County Road 31 => County Road 31
# County Road  31 => County Road  31
# Sexton Sideroad => Sexton Sideroad
# Lowes Sideroad => Lowes Sideroad
# Middle Sideroad => Middle Sideroad
# Naylor Sideroad => Naylor Sideroad
# Gracey Sideroad => Gracey Sideroad
# Wilson Sideroad => Wilson Sideroad
# Richardson Sideroad => Richardson Sideroad
# Comber Sideroad => Comber Sideroad
# Batton Sideroad => Batton Sideroad
# Graham Sideroad => Graham Sideroad
# Trembley Sideroad => Trembley Sideroad
# Olinda Sideroad => Olinda Sideroad
# North Sideroad => North Sideroad
# Mole Sideroad => Mole Sideroad
# Cottam Sideroad => Cottam Sideroad
# Gesto Sideroad => Gesto Sideroad
# Marsh Sideroad => Marsh Sideroad
# Beaudoin Sideroad => Beaudoin Sideroad
# Hyland Sideroad => Hyland Sideroad
# Brush Sideroad => Brush Sideroad
# Ellis Sideroad => Ellis Sideroad
# Coulter Sideroad => Coulter Sideroad
# McCain Sideroad => McCain Sideroad
# Ferris Sideroad => Ferris Sideroad
# O'brien Sideroad => O'brien Sideroad
# Briton Sideroad => Briton Sideroad
# Upcott Sideroad => Upcott Sideroad
# Hopgood Sideroad => Hopgood Sideroad
# Inman Sideroad => Inman Sideroad
# Walker Sideroad => Walker Sideroad
# County Road 37 => County Road 37
# East M 36 => East M 36
# County Road 34 => County Road 34
# Interpark Dr N => Interpark Dr North
# Carolina Woods => Carolina Woods
# Edmund Pl. => Edmund Place
# Cottage Pl. => Cottage Place
# Carpenter road => Carpenter road
# Packard road => Packard road
# Maple Row => Maple Row
# 29217 Wagner => 29217 Wagner
# Quincy => Quincy
# Vinewood St. => Vinewood Street
# Griswold St. => Griswold Street
# Brush St. => Brush Street
# Rockwood St. => Rockwood Street
# Alfred St. => Alfred Street
# Grove St. => Grove Street
# N. Main St. => N. Main Street
# Church St. => Church Street
# Jerome St. => Jerome Street
# South Forest => South Forest
# ...
# Little Mack Ave => Little Mack Avenue
# Equestrian => Equestrian
# Marquette Ct => Marquette Court
# Stone Wood Ct => Stone Wood Court
# Victoria Ct => Victoria Court
# Armstrong Ct => Armstrong Court
# W. Coolidge => W. Coolidge
# Davison => Davison
# Belmont => Belmont
# East Square Lake => East Square Lake
# E Long Lake => E Long Lake
# E Hamlin => E Hamlin
# E 14 st lockport il => E 14 st lockport il
# bordeaux ave => bordeaux ave
# Southfield Expressway => Southfield Expressway
# Marentette Beach => Marentette Beach
# South Dixie Highway => South Dixie Highway
# West Vernor Highway => West Vernor Highway
# Northwestern Highway => Northwestern Highway
# South Ballenger Highway => South Ballenger Highway
# Schaefer Highway => Schaefer Highway
# Groesbeck Highway => Groesbeck Highway
# Fred W. Moore Highway => Fred W. Moore Highway
# Sand Creek Highway => Sand Creek Highway
# Ford Highway => Ford Highway
# North Dixie Highway => North Dixie Highway
# Dixie Highway => Dixie Highway
# Old US-12 Highway => Old US-12 Highway
# South Industrial Highway => South Industrial Highway
# North Ballenger Highway => North Ballenger Highway
# Coolidge Highway => Coolidge Highway
# South Dort Highway => South Dort Highway
# Stephenson Highway => Stephenson Highway
# Hane Highway => Hane Highway
# Tecumseh-Clinton Highway => Tecumseh-Clinton Highway
# Northeastern Highway => Northeastern Highway
# Wolf Creek Highway => Wolf Creek Highway
# Dix Highway => Dix Highway
# West McNichols => West McNichols
# E. Tienken Rd. => E. Tienken Road
# Consear Rd. => Consear Road
# E 12 Mile Rd. => E 12 Mile Road
# Lauzon Rd. => Lauzon Road
# Sashabaw Rd. => Sashabaw Road
# Citation Triangle => Citation Triangle
# County Road 46 => County Road 46
# Lichfield => Lichfield
# County Road 42 => County Road 42
# Old US-23 => Old US-23
# Highway 40 => Highway 40
# Green Hill Road Apt 40 => Green Hill Road Apt 40
# County Road 41 => County Road 41
# Kent Road 1 => Kent Road 1
# Concession Road 1 => Concession Road 1
# Concession Road 5 => Concession Road 5
# Country Bluff => Country Bluff
# Stephenson Hwy => Stephenson Highway
# Coolidge Hwy => Coolidge Highway
# County Road 9 => County Road 9
# Concession Road 9 => Concession Road 9
# Town Center Dr => Town Center Drive
# Sierra Dr => Sierra Drive
# E. Fisher Service Dr => E. Fisher Service Drive
# Shoreline Dr => Shoreline Drive
# E. Huron River Dr => E. Huron River Drive
# Corporate Dr => Corporate Drive
# Essex Dr => Essex Drive
# Tallman Dr => Tallman Drive
# West Eisenhower => West Eisenhower
# Lepain Crescent => Lepain Crescent
# Astor Crescent => Astor Crescent
# Heritage Garden Crescent => Heritage Garden Crescent
# Branton Crescent => Branton Crescent
# Granby Crescent => Granby Crescent
# Woodward Crescent => Woodward Crescent
# Dunlop Crescent => Dunlop Crescent
# Mountbatten Crescent => Mountbatten Crescent
# Turner Crescent => Turner Crescent
# Seymour Crescent => Seymour Crescent
# Paul Crescent => Paul Crescent
# Willowdale Crescent => Willowdale Crescent
# Clairwood Crescent => Clairwood Crescent
# Lonsdale Crescent => Lonsdale Crescent
# Templeton Crescent => Templeton Crescent
# Woodland Crescent => Woodland Crescent
# Juliet Crescent => Juliet Crescent
# Socrates Crescent => Socrates Crescent
# Eastgrove Crescent => Eastgrove Crescent
# Kerr Crescent => Kerr Crescent
# Paula Crescent => Paula Crescent
# St Luke Crescent => St Luke Crescent
# Elsfield Crescent => Elsfield Crescent
# Beniuk Crescent => Beniuk Crescent
# Azalia Crescent => Azalia Crescent
# Ashfield Crescent => Ashfield Crescent
# Lemonwood Crescent => Lemonwood Crescent
# Barcelona Crescent => Barcelona Crescent
# Guildwood Crescent => Guildwood Crescent
# Shenandoah Crescent => Shenandoah Crescent
# Hillview Crescent => Hillview Crescent
# Cortina Crescent => Cortina Crescent
# Sterling Crescent => Sterling Crescent
# Stoneybrook Crescent => Stoneybrook Crescent
# Moceri Crescent => Moceri Crescent
# Mayrand Crescent => Mayrand Crescent
# McMahon Crescent => McMahon Crescent
# Whites Crescent => Whites Crescent
# Kingston Crescent => Kingston Crescent
# Lovell Crescent => Lovell Crescent
# Spaco Crescent => Spaco Crescent
# Christina Crescent => Christina Crescent
# Boulder Crescent => Boulder Crescent
# Rushwood Crescent => Rushwood Crescent
# Cranbrook Crescent => Cranbrook Crescent
# Woodlawn Crescent => Woodlawn Crescent
# Helsinki Crescent => Helsinki Crescent
# Aurelia Crescent => Aurelia Crescent
# Faholo Crescent => Faholo Crescent
# Teedie Crescent => Teedie Crescent
# Katrishe Crescent => Katrishe Crescent
# Tracey Crescent => Tracey Crescent
# Sylvano Crescent => Sylvano Crescent
# Tuscany Crescent => Tuscany Crescent
# Shelley Crescent => Shelley Crescent
# Taylor Crescent => Taylor Crescent
# Briarwood Crescent => Briarwood Crescent
# Pineview Crescent => Pineview Crescent
# Sugarwood Crescent => Sugarwood Crescent
# Maple Leaf Crescent => Maple Leaf Crescent
# Brownlee Crescent => Brownlee Crescent
# Pinewood Crescent => Pinewood Crescent
# Imperial Crescent => Imperial Crescent
# Lydia Crescent => Lydia Crescent
# Fuller Crescent => Fuller Crescent
# Brock Crescent => Brock Crescent
# Aristotle Crescent => Aristotle Crescent
# Candlewood Crescent => Candlewood Crescent
# Brouillette Crescent => Brouillette Crescent
# Grand View Crescent => Grand View Crescent
# Queens Hill Crescent => Queens Hill Crescent
# St Thomas Crescent => St Thomas Crescent
# Mill Crescent => Mill Crescent
# Bayview Crescent => Bayview Crescent
# Satinwood Crescent => Satinwood Crescent
# Erindale Crescent => Erindale Crescent
# Malden Crescent => Malden Crescent
# Mill Creek Crescent => Mill Creek Crescent
# Blackthorn Crescent => Blackthorn Crescent
# Forest Hill Crescent => Forest Hill Crescent
# Pinetree Crescent => Pinetree Crescent
# Red Oak Crescent => Red Oak Crescent
# Shady Springs Crescent => Shady Springs Crescent
# Burbank Crescent => Burbank Crescent
# Meadowland Crescent => Meadowland Crescent
# Fairway Crescent => Fairway Crescent
# Palms Crescent => Palms Crescent
# Robin Crescent => Robin Crescent
# Courtland Crescent => Courtland Crescent
# Cardinal Crescent => Cardinal Crescent
# Allison Crescent => Allison Crescent
# Elizabeth Crescent => Elizabeth Crescent
# Cedar Crescent => Cedar Crescent
# Baker Crescent => Baker Crescent
# Woodmont Crescent => Woodmont Crescent
# Solar Crescent => Solar Crescent
# Sumach Crescent => Sumach Crescent
# Keating Crescent => Keating Crescent
# St Agnes Crescent => St Agnes Crescent
# Barton Crescent => Barton Crescent
# David Crescent => David Crescent
# Beth Crescent => Beth Crescent
# Vernon Crescent => Vernon Crescent
# Horwood Crescent => Horwood Crescent
# Thompson Crescent => Thompson Crescent
# Atwater Crescent => Atwater Crescent
# Parkland Crescent => Parkland Crescent
# Villa Paradiso Crescent => Villa Paradiso Crescent
# Hope Crescent => Hope Crescent
# Brush Crescent => Brush Crescent
# Gardiner Crescent => Gardiner Crescent
# Gignac Crescent => Gignac Crescent
# Sylvestre Crescent => Sylvestre Crescent
# Timber Bay Crescent => Timber Bay Crescent
# Hunt Club Crescent => Hunt Club Crescent
# Halo Crescent => Halo Crescent
# Philip Crescent => Philip Crescent
# Marlo Crescent => Marlo Crescent
# Matthew Crescent => Matthew Crescent
# Marie Crescent => Marie Crescent
# Sherway Crescent => Sherway Crescent
# Tumbleweed Crescent => Tumbleweed Crescent
# Marina Grove Crescent => Marina Grove Crescent
# Elmwood Crescent => Elmwood Crescent
# Bramley Crescent => Bramley Crescent
# Helena Crescent => Helena Crescent
# Border Crescent => Border Crescent
# Winston Crescent => Winston Crescent
# Elmgate Crescent => Elmgate Crescent
# Cada Crescent => Cada Crescent
# Champ Crescent => Champ Crescent
# Coram Crescent => Coram Crescent
# Helen Crescent => Helen Crescent
# Smith Crescent => Smith Crescent
# Alan Crescent => Alan Crescent
# Holly Crescent => Holly Crescent
# Hansen Crescent => Hansen Crescent
# Simard Crescent => Simard Crescent
# Andrew Crescent => Andrew Crescent
# Donald Crescent => Donald Crescent
# Kael Crescent => Kael Crescent
# Whistler Crescent => Whistler Crescent
# Higgins Crescent => Higgins Crescent
# Crozier Crescent => Crozier Crescent
# Regency Crescent => Regency Crescent
# Montgomery Crescent => Montgomery Crescent
# Stewart Crescent => Stewart Crescent
# George Crescent => George Crescent
# Fischer Crescent => Fischer Crescent
# Mitchell Crescent => Mitchell Crescent
# Remo Crescent => Remo Crescent
# Murray Crescent => Murray Crescent
# Collier Crescent => Collier Crescent
# Funaro Crescent => Funaro Crescent
# Mark Crescent => Mark Crescent
# Dieppe Crescent => Dieppe Crescent
# Lawson Crescent => Lawson Crescent
# James Crescent => James Crescent
# Emma Maria Crescent => Emma Maria Crescent
# Martin Crescent => Martin Crescent
# Whitefish Crescent => Whitefish Crescent
# Golfwood Crescent => Golfwood Crescent
# Naples Crescent => Naples Crescent
# Willow Crescent => Willow Crescent
# Park Crescent => Park Crescent
# Maplewood Crescent => Maplewood Crescent
# Acorn Crescent => Acorn Crescent
# Mount Sinai Crescent => Mount Sinai Crescent
# Cherrylawn Crescent => Cherrylawn Crescent
# Montego Bay Crescent => Montego Bay Crescent
# Lucy Crescent => Lucy Crescent
# Hanley Crescent => Hanley Crescent
# Daneila Crescent => Daneila Crescent
# Masotti Crescent => Masotti Crescent
# Chornoby Crescent => Chornoby Crescent
# Cobblestone Crescent => Cobblestone Crescent
# Fairlea Crescent => Fairlea Crescent
# Molnar Crescent => Molnar Crescent
# Wawa Crescent => Wawa Crescent
# Redwood Crescent => Redwood Crescent
# Golfcourse Crescent => Golfcourse Crescent
# Bayfield Crescent => Bayfield Crescent
# Turnhout Crescent => Turnhout Crescent
# Manitou Crescent => Manitou Crescent
# Diane Crescent => Diane Crescent
# Mousseau Crescent => Mousseau Crescent
# Michael Crescent => Michael Crescent
# Jacie Crescent => Jacie Crescent
# Sorge Crescent => Sorge Crescent
# Cartier Crescent => Cartier Crescent
# Alta B Crescent => Alta B Crescent
# Giselle Crescent => Giselle Crescent
# Hickory Crescent => Hickory Crescent
# Osborn Crescent => Osborn Crescent
# Sunnybrook Crescent => Sunnybrook Crescent
# Mickaila Crescent => Mickaila Crescent
# Heatherglen Crescent => Heatherglen Crescent
# Gary Crescent => Gary Crescent
# Canary Crescent => Canary Crescent
# Troup Crescent => Troup Crescent
# Darlington Crescent => Darlington Crescent
# Lake Crescent => Lake Crescent
# Garvey Crescent => Garvey Crescent
# Klundert Crescent => Klundert Crescent
# Brenda Crescent => Brenda Crescent
# Littler Crescent => Littler Crescent
# Birchwood Crescent => Birchwood Crescent
# Patrick Crescent => Patrick Crescent
# Chelsea Crescent => Chelsea Crescent
# Sand Pebble Crescent => Sand Pebble Crescent
# Centennial Crescent => Centennial Crescent
# Innerkip Crescent => Innerkip Crescent
# Marlene Crescent => Marlene Crescent
# Amberly Crescent => Amberly Crescent
# Van Crescent => Van Crescent
# Erie Glen Crescent => Erie Glen Crescent
# Cambridge Crescent => Cambridge Crescent
# Greenwood Crescent => Greenwood Crescent
# Thornberry Crescent => Thornberry Crescent
# Community Crescent => Community Crescent
# South Wind Crescent => South Wind Crescent
# Gregory Crescent => Gregory Crescent
# Appletree Crescent => Appletree Crescent
# Hyatt Crescent => Hyatt Crescent
# Harbourne Crescent => Harbourne Crescent
# Linda Crescent => Linda Crescent
# Midfield Crescent => Midfield Crescent
# Alderbury Crescent => Alderbury Crescent
# Southwest Crescent => Southwest Crescent
# Bluewater Crescent => Bluewater Crescent
# Burdick Crescent => Burdick Crescent
# Carling Crescent => Carling Crescent
# Lynngrove Crescent => Lynngrove Crescent
# Shadetree Crescent => Shadetree Crescent
# Angstrom Crescent => Angstrom Crescent
# Meander Crescent => Meander Crescent
# Halstead Crescent => Halstead Crescent
# Binder Crescent => Binder Crescent
# Ashley Crescent => Ashley Crescent
# Assiniboine Crescent => Assiniboine Crescent
# Thorn Ridge Crescent => Thorn Ridge Crescent
# Providence Crescent => Providence Crescent
# Bayswater Crescent => Bayswater Crescent
# Mei Lin Crescent => Mei Lin Crescent
# Kenwood Crescent => Kenwood Crescent
# Bayberry Crescent => Bayberry Crescent
# Holmes Crescent => Holmes Crescent
# Parkdale Crescent => Parkdale Crescent
# Mount Pleasant Crescent => Mount Pleasant Crescent
# Brentwood Crescent => Brentwood Crescent
# Driftwood Crescent => Driftwood Crescent
# Blairwood Crescent => Blairwood Crescent
# Carolina Woods Crescent => Carolina Woods Crescent
# St. Thomas Crescent => St. Thomas Crescent
# Brunelle Crescent => Brunelle Crescent
# St Martin Crescent => St Martin Crescent
# Ancona Crescent => Ancona Crescent
# Lombardy Crescent => Lombardy Crescent
# Wildberry Crescent => Wildberry Crescent
# Roxbury Crescent => Roxbury Crescent
# Eagle Crescent => Eagle Crescent
# Clydesdale Crescent => Clydesdale Crescent
# Fasan Crescent => Fasan Crescent
# Katie Crescent => Katie Crescent
# Royal Crescent => Royal Crescent
# Hawthorn Crescent => Hawthorn Crescent
# Massimo Crescent => Massimo Crescent
# Brookview Crescent => Brookview Crescent
# Fairlane Crescent => Fairlane Crescent
# Glenesk Crescent => Glenesk Crescent
# Deerview Crescent => Deerview Crescent
# Cairns Crescent => Cairns Crescent
# Cooper Crescent => Cooper Crescent
# Peach Blossom Crescent => Peach Blossom Crescent
# Caribou Crescent => Caribou Crescent
# Tennessee Crescent => Tennessee Crescent
# Clearview Crescent => Clearview Crescent
# North Center Street, Suite 203 => North Center Street, Suite 203
# Wilshire Drive, Suite 202 => Wilshire Drive, Suite 202
# Tecumseh Rd E => Tecumseh Rd East
# Middlebelt => Middlebelt
# Rue Labbe => Rue Labbe
# Highway 77 => Highway 77
# Eastgate Estates => Eastgate Estates
# Cass => Cass
# Canada South Railway => Canada South Railway
# Charles H Orndorf => Charles H Orndorf
# Lexham Gardens => Lexham Gardens
# St Clair Gardens => St Clair Gardens
# Marvin Gardens => Marvin Gardens
# Victoria Avenue South => Victoria Avenue South
# Walnut Street South => Walnut Street South
# Talbot Street South => Talbot Street South
# Floralview Drive South => Floralview Drive South
# Spruce Street South => Spruce Street South
# Equestrian South => Equestrian South
# Little Street South => Little Street South
# East Street South => East Street South
# Indian Road South => Indian Road South
# Main Street South => Main Street South
# Prince Albert Street South => Prince Albert Street South
# Laird Avenue South => Laird Avenue South
# Palmerston Street South => Palmerston Street South
# Forsyth Street South => Forsyth Street South
# Sandwich Street South => Sandwich Street South
# Euphemia Street South => Euphemia Street South
# Brock Street South => Brock Street South
# College Avenue South => College Avenue South
# Division Street South => Division Street South
# Mitton Street South => Mitton Street South
# Walnut Avenue South => Walnut Avenue South
# Concession Road 6 South => Concession Road 6 South
# Cherry Lane South => Cherry Lane South
# Vidal Street South => Vidal Street South
# Village Circle South => Village Circle South
# Christina Street South => Christina Street South
# Ridgeview Place South => Ridgeview Place South
# Hanlan Street South => Hanlan Street South
# Lambeth Court South => Lambeth Court South
# Queen Street South => Queen Street South
# Fort Street South => Fort Street South
# Balaclava Street South => Balaclava Street South
# Secord Street South => Secord Street South
# Justras Drive South => Justras Drive South
# Victoria Street South => Victoria Street South
# Erie Street South => Erie Street South
# Townline Road Malden Colchester South => Townline Road Malden Colchester South
# Villa Maria Boulevard South => Villa Maria Boulevard South
# Concession Road 4 South => Concession Road 4 South
# South Talbot Road South => South Talbot Road South
# MacKenzie Street South => MacKenzie Street South
# Front Street South => Front Street South
# Alice Street South => Alice Street South
# Concession Road 5 South => Concession Road 5 South
# Wilder Drive South => Wilder Drive South
# Russell Street South => Russell Street South
# Front Road South => Front Road South
# Arthur Street South => Arthur Street South
# Milne Street South => Milne Street South
# Delmer Crescent South => Delmer Crescent South
# Roseland Drive South => Roseland Drive South
# Garfield => Garfield
# Creek Bend => Creek Bend
# Harvest Bend => Harvest Bend
# Horseshoe Bend => Horseshoe Bend
# Country Village => Country Village
# W South Blvd => W South Boulevard
# W Boston Blvd => W Boston Boulevard
# 46596 => 46596
# Van Dyke => Van Dyke
# 35275 Silver Maple => 35275 Silver Maple

# %%
city = set()
postcode = set()

for _, element in ET.iterparse(filename, events=('end',)):
    for child in element.iter('tag'):
        if 'addr:' in child.attrib['k']:
            
            if re.search(r'addr:city$', child.attrib['k']):
                city.add(child.attrib['v'])

            elif re.search(r'addr:postcode$', child.attrib['k']):
                postcode.add(child.attrib['v'])
                
           
print "city: {}\n".format(city)

print "postcode: {}\n".format(postcode)
# Out:
# city: set(['Ypsilanti', 'Trowbridge', 'Tecumseh', 'Maybee', 'Northville Township', 'Casco', 'Dundee', 'brownstown township', 'troy', 'Wayne', 'Lennon', 'Clyde Township', 'lincoln park', 'Detroit, MI', 'Romeo', 'Shelby Township', 'Milford', 'Highland', 'Madison Heights', 'Goodrich', 'Whitmore Lake', 'Leonard', 'highland Park', 'Ann Arbor', 'Lapeer', 'Flint', 'Pinckney', 'Rochester Hills', 'Municipality of Leamington', 'Dearborn', 'Bloomfield Hills', 'Belle River', 'Sarnia 45', 'Montrose', 'Garden City', 'New Hudson', 'Dryden', 'Port Huron', 'Burtchville', 'flint', 'City of Sault Ste. Marie', 'Lincoln Park', 'hamtramck', 'Chesterfield', 'Pittsfield Charter Township', 'Inkster', 'Kimball', 'Erie', 'Washington', 'White Lake Township', 'Township of St. Clair', 'Harrow', 'Center Line', 'Redford', 'Troy', 'Livonia', 'Manchester', 'Columbiaville', 'Lambertville', 'Hazel Park', 'Ray', 'Saint Clair Shores', 'Windsor', 'Warren', 'Fraser', 'Rochester', 'Novi', 'Metamora', 'Commerce Charter Township', 'MACOMB', 'Shelby Charter Township', 'Durand', 'Petersburg', 'rochester Hills', 'Riverview', 'Sarnia', 'Linden', 'Onsted', 'Pontiac', 'Westland', 'Ford of Canada - Essex Engine Plant', 'South Lyon', 'Macomb', 'Grosse Point Farms', 'shelby township', 'Clarkson', 'Toledo', 'Ottawa Lake', 'Leamington', 'Maidstone', 'Highland Park', 'Commerce', 'Ottawa', 'Brownstown', 'Redford Charter Township', 'Imlay City', 'Davisburg', 'Hartland', 'Commerce Township', 'Grosse Pointe Woods', 'Berkley', 'Fenton', 'Madison Heights, MI', 'West Bloomfield Township', 'Carleton', 'Attica', 'Taylor', 'Clinton', 'Municipality of Chatham-Kent', 'Auburn Hills', 'Plymouth', 'Rochester, MI', 'Washington Township', 'Superior Township', 'Brighton, MI', 'Wixom', 'highland', 'Redford Township', 'Ford of Canada - Annex', 'Saline', 'Dexter', 'Grosse Ile', 'Sterling Heights', 'Farminton Hills', 'Mt. Clemens', 'Canton', 'New Baltimore', 'Marion Township', 'Flushing', 'Waterford', 'Bloomfield Township', 'Northville', 'Clawson', 'Ecorse', 'Ford of Canada - Windsor Engine Plant', 'Walled lake', 'Southgate', 'Mount Clemens', 'Town of Essex', 'South Rockwood', 'City of Sarnia', 'Hamtramck', 'Grosse Ile Township', 'Memphis', 'White Lake', 'Brighton', 'Davison', 'milford', 'Columbus Township', 'Ridgeway', 'Walled Lake', 'Utica', 'Northville  Township', 'East China Township', 'Detroit', 'River Rouge', 'Emmett', 'Belleville', 'New Haven', 'Ortonville', 'Franklin', 'Adrian', 'Temperance', 'Bruce Township', 'Chelsea', 'Village of Point Edward', 'Southfield', 'Tecumesh', 'Plymouth Township', 'Orchard Lake', 'Grand Blanc', 'Byron', 'Gregory', 'Roseville', 'Salem', 'Birmingham', 'Burtchville Township', 'Burton', '2515', 'Milan', 'Jeddo', 'Grosse Pointe Farms', 'West Bloomfield', 'Sylvan Lake', 'Macomb Township', 'Farmington', '48192', 'Fenton Township', 'Fowlerville', 'Dearborn Heights', 'Essex', 'Lake Orion', 'Corunna', 'City of Windsor', 'Holly', 'Ray Township', 'Fort Gratiot', 'Walpole Island 46', 'Town of Lasalle', 'rochester', 'Eastpointe', 'Grand Blanc Township', 'Belle Isle', 'Farmington Hills', 'York Township', 'Orion Township', 'St. Clair', 'Oxford', 'Town of Amherstburg', 'Ferndale', 'Newport', 'Grosse Pointe Park', 'Tipton', 'Town of Lakeshore', 'Marysville', 'Township of Pelee', 'Wyandotte', 'Saint Clair', 'Howell', 'Amherstburg', 'Oak Park', 'Fort Gratiot Township', 'Woodhaven', 'Trenton', 'Almont', 'Clarkston', 'Oakland Township', 'Ypsilanti Township', 'Beverly Hills', 'Town of Tecumseh', 'Dearborn Michigan', 'Romulus', 'Clinton Township', 'Royal Oak', 'Harrison Township', 'Allen Park', 'Town of Kingsville', 'Swartz Creek', 'Orion Charter Township', 'Oakland', 'detroit', 'Monroe'])
#
# postcode: set(['48117', '48116', '48442', '48444', '48111', '48446', '48449', '48118', '48114', '48529', 'N7T 1P4', 'N0R 1A0', '39267', '48439-1943', '48063', '48060', '48067', '48066', '48065', '48064', '48068', 'N9E 1B6', 'N8A0B2', '48309-4401', 'N7V 3Z3', 'N8S 1K9', 'N8Y 1N9', '49286', '49287', 'MI 48170', 'N9A 2X1', '49267', '49265', 'N9E 1P6', '48390', '48393', 'N9V 2A9', '48238', '48855', '48367', '48360', '48361', '48362', '48363', '48242', '48240', '48026', '48025', '40183', '48022', '48021', '48230', '48418', '48144', '48146', '48412', '48141', 'N7T 7W5', '48092', '48093', '48096', '48094', '48095', 'N9C 2J9', '48098', 'N9A5T2', 'N7T 4K7', '48532', 'N9V 1A9', 'N8S 1W8', 'N8S 1W4', '48178-8798', '48243-1312', '48235-2356', 'N8Y 1K3', 'N8Y 1R7', '48836-8304', '48178-9998', '48375-1739', 'N8S 0A1', 'N8H1N2', '48359', 'N9A 2T1', '48357', '48356', '48350', 'N8Y 2K5', '48817', '49221', '48103-9300', '49224', '48328', '48329', '48320', '48322', '48323', '48324', '48326', '48327', '48101', '48103', '48104', '48105', '48106', '48455', '48390-3082', '48109', 'N7T 7S3', 'N8S 1N3', '48205', '48108-9514', '48214', '48215', '48216', '48217', '48210', '48211', '48212', '48213', '48197', '48195', '48193', '48192', 'N8W 3P8', '48117-0267', '48174', '48176', '48079', '48173', '48074', '48075', '48076', '48179', '48178', '48072', '48073', 'N9G 1X3', '48192-5709', 'N8H 1M5', 'N9A 3A1', 'N9H 2P7', '48506', '48451', '48312-4662', '48229', '48228', '48225', '48224', '48227', '48226', '48221', '48220', '48223', '48462', '48382', '48383', '48380', '48381', '48386', 'N8H 4N9', '48310', '48313', '48312', '48315', '48314', '48317', '48316', 'N8S 4S5', '48030', '48032', '48033', '48034', '48035', 'N8T 2H9', '48037', '48038', '48138', '48429', '48428', '48423', '48130', '48133', '48135', '48134', '48137', 'N8S 2B5', 'N7T 7B4', '48198', '48045', '48044', '48047', '48046', '48040', '48043', '48042', '48049', '48048', 'MI 48187', '48430-9418', '48073-0923', 'N9A 5K9', 'MI 48230', '48073-6748', '48095-2555', '48066-4879', '48237', 'N9A 2T2', '48348', '48346', '48342', '48340', '48341', '48353', 'N7T 5S6', 'N8H 5C7', 'N9A 1P2', 'N9A 5P8', '48235', 'N9B 3A9', '48504', 'N7T 6X8', '48507', '48502', '48503', '48509', '48381-1759', 'N8X1T5', '48188', '48189', '48180', '48182', '48183', '48184', '48185', '48186', '48187', '48009', '48167', '48164', '48165', '48162', '48160', '48161', '48003', '48168', '48169', '48166', '48336-3121', 'MI 48374', 'N8H 1L6', '48036', 'N9A 1S9', 'N9A 1S8', 'N8S 3N1', '41892', 'N8T 1B1', 'N8Y 1L4', 'N8S 1G8', '48239', '48236', '483352', '48234', '48109-1357', 'N7T 1J5', '48131', 'N0R 1K0', 'N9V 1X2', '48421', '48457', '48197-9606', '48109-1285', '48302', '48108', '48301', '48306', '48307', '48304', '48111-1133', '48309', '48430', '48433', '48068-9998', '48438', '48439', '48128', '48120', 'MI 48108', '48126', '48127', '48124', '48125', 'N8W 4J2', 'N9B 3P4', 'N9E 2T6', 'N8S 1E6', '48054', '48051', '48059', '48167-3958', 'N9V 4A9', 'N7T 2W2', '481241', 'N8H 3C2', 'ON N8N 0B8', '49022', 'N8P 1L7', '49203', '48371', '48370', '48377', '48131-9572', '48375', '48374', '48836', 'N8S 4V2', 'N0N 1G0', '43611', '43613', 'N7T 1H1', '484298', '48473', '48170-3907', '49270', '49279', '48218', '48843', '48219', '48152', '48150', '48154', '48013', '48159', '48158', '48017', 'N8W4J5', '48015', '48081', '48080', '48083', '48082', '48085', '48084', '48072-1627', '48089', '48088', '448212', 'N8H3V4', 'N9G 2L9', 'N8M 2N8', 'N9A 4X3', 'N9e2Y7', 'N9A 3C5', '48170', '48375-1833', 'N8X 2T2', '48071', 'N8W 5X3', '48209', '48208', '48203', '48202', '48201', '48207', '48206', 'N8W 1B7', '48204', '49236', '48334', '48337', '48336', '48335', 'N9M 2W3', '48331'])

# %%
def fix_postal_code(postcode):
    sep = '-'
    postcode = postcode.strip()
    # check if postcode has a '-' separator
    if sep in postcode:
        # split returns a list
        codesList = postcode.split(sep, 1)
        # select the part of 'postcode' before the `-`
        # strip whitespaces.
        postcode = codesList[0].strip()
    if "MI" in postcode:
        # if "MI" is in postcode, remove it:
        postcode = postcode.replace("MI", "").strip()
    if "N" in postcode:
        # if "N" is in postcode, add a space after 3 characters:
        # where 'postcode[:3]' is 'slicing' the string
        postcode = postcode[:3] + ' ' + postcode[3:]
    # output is updated postcode if cleaned, or the original postcode if not
    # in either case, strip whitespace
    postcode = postcode.strip()
    # in "N" postcodes, there may have already been a space
    # so we would want to remove the extra one
    postcode = " ".join(postcode.split())
    return postcode

# %%
check = ['MI64433-4233',' N64431-4233','MI74213','  MI64434  ','  N64434  ',' N64 434']

for entry in check:
    print fix_postal_code(entry)
# Out:
# 64433
# N64 431
# 74213
# 64434
# N64 434
# N64 434

# %%
def fix_cities(city):
    # create an empty string (which will be used to piece the city name 
    # back together again later in the code):
    city1 = ''
    # again, split creates a list (in this case, of each word in the city name)
    # where the default is to split at whitespace:
    cityList = city.split()
    # loop over the words in the city name, capitalize by splicing:
    for ind in cityList:
        # piece the city name back together again, using the empty string 'city1'
        city1 += ind[:1].upper() + ind[1:] + " "
    city = city1.strip()
    return city

# %%
import csv
import codecs
import copy
import cerberus
import schema

OSM_PATH = filename

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""
    node_attribs = {} 
    way_attribs = {}
    way_nodes = []
    tags = []
    
    if element.tag=='node':
        for i in node_attr_fields:
            node_attribs[i]=element.attrib[i]
            
    if element.tag=='way':
        for i in way_attr_fields:
            way_attribs[i]=element.attrib[i]
     
    for tag in element.iter("tag"):
        tag_dict={}
        attributes=tag.attrib
        if problem_chars.search(tag.attrib['k']):
            continue
        if element.tag=='node':
            tag_dict['id']=node_attribs['id']
        else:
            tag_dict['id']=way_attribs['id']
        tag_dict['value']=attributes['v']
        # if there is a certain signifying key, update/fix the street name, city name, and postal code 
        if tag.attrib['k'] == 'addr:street':
            tag_dict['value'] = update_name(tag.attrib['v'], mapping)
        elif tag.attrib['k'] == 'addr:city':
            tag_dict['value'] = fix_cities(tag.attrib['v'])
        elif tag.attrib['k'] == 'addr:postcode':
            tag_dict['value'] = fix_postal_code(tag.attrib['v'])
        else:
            pass
        lc=LOWER_COLON.search(tag.attrib['k'])
        if lc:
            before_colon = re.findall('^(.+?):', tag.attrib['k'])
            after_colon = re.findall('^[a-z|_]+:(.+)', tag.attrib['k'])
            try:
                tag_dict['type'] = before_colon[0]
            except:
                print tag.attrib['k']
            try:
                tag_dict['key'] = after_colon[0]
            except:
                print tag.attrib['k']
        else:
            tag_dict['key']=attributes['k']
            tag_dict['type']='regular'
        tags.append(tag_dict)
    
    if element.tag=='way':
        count=0
        for nd in element.iter("nd"):
            way_node_dict={}
            way_node_dict['id']=way_attribs['id']
            way_node_dict['node_id']=nd.attrib['ref']
            way_node_dict['position']= count
            count += 1
            way_nodes.append(way_node_dict)
    
    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)
